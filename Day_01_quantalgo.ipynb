# %%
# Basic math
x = 1023.225
y = -20.5
total = x + y
print(f"Total is: {total}")
# Out:
# Total is: 1002.725

# %%
# Today's date
from datetime import datetime
today = datetime.now()
print(f"Today is: {today}")
# Out:
# Today is: 2026-01-03 12:59:51.491493
