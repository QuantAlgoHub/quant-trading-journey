# %%
# Basic math
x = 102.2
y = -20.1
total = x + y
print(f"Total is: {total}")
# Out:
# Total is: 82.1

# %%
# Today's date
from datetime import datetime
today = datetime.now()
print(f"Today is: {today}")
# Out:
# Today is: 2026-01-03 12:42:02.742390
